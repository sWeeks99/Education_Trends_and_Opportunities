# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress, pearsonr
import os

# %%
df = pd.read_csv("../data/college_clean.csv")
df
# Out:
#                          School Name Private   Apps  Accept  Tuition/Semester  \
# 0       Abilene Christian University     Yes   1660    1232              7440
# 1                 Adelphi University     Yes   2186    1924             12280
# 2                     Adrian College     Yes   1428    1097             11250
# 3                Agnes Scott College     Yes    417     349             12960
# 4          Alaska Pacific University     Yes    193     146              7560
# ..                               ...     ...    ...     ...               ...
# 448  Worcester Polytechnic Institute     Yes   2768    2314             15884
# 449                Xavier University     Yes   1959    1805             11520
# 450   Xavier University of Louisiana     Yes   2097    1915              6900
# 451                  Yale University     Yes  10705    2453             19840
# 452     York College of Pennsylvania     Yes   2989    1855              4990
#
#      Personal Spending/Semester  Book Costs/Semester  Room & Board/Semester  \
# 0                          2200                  450                   3300
# 1                          1500                  750                   6450
# 2                          1165                  400                   3750
# 3                           875                  450                   5450
# 4                          1500                  800                   4120
# ..                          ...                  ...                    ...
# 448                         730                  530                   5370
# 449                        1250                  600                   4960
# 450                         781                  617                   4200
# 451                        2115                  630                   6510
# 452                        1250                  500                   3560
#
#      Early Career Pay  Mid-Career Pay  % STEM Degrees  % Grad rate  \
# 0             61500.0        110800.0               7           60
# 1             64500.0        108000.0               8           56
# 2             52400.0         89200.0              11           54
# 3             58300.0         99400.0              20           59
# 4             59700.0        102000.0               1           15
# ..                ...             ...             ...          ...
# 448           89100.0        161000.0              86           82
# 449           64400.0        112900.0               5           83
# 450           54200.0        102200.0              33           49
# 451           89700.0        168300.0              27           99
# 452           63500.0        103100.0              19           99
#
#      Total Cost/Semester  Acceptance Rate
# 0                  13390         0.742169
# 1                  20980         0.880146
# 2                  16565         0.768207
# 3                  19735         0.836930
# 4                  13980         0.756477
# ..                   ...              ...
# 448                22514         0.835983
# 449                18330         0.921388
# 450                12498         0.913209
# 451                29095         0.229145
# 452                10300         0.620609
#
# [453 rows x 14 columns]

# %%
# Pie Graphs
pie1_data = df['Private'].value_counts()
labels = "Private", "Public"
explode = (0.1, 0)
plt.figure(figsize=(5,5))
plt.pie(pie1_data, labels=labels, explode=explode, shadow=True, autopct='%1.1f%%')
plt.title ("Private vs Public Colleges")
# Out:
# Text(0.5, 1.0, 'Private vs Public Colleges')
